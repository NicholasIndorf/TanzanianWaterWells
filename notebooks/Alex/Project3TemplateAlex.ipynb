# %% [markdown]
# # Project Title

# %% [markdown]
# ## Overview
#
# A one-paragraph overview of the project, including the business problem, data, methods, results and recommendations.
#
# ## Business Problem
#
# Summary of the business problem you are trying to solve, and the data questions that you plan to answer to solve them.
#
# Questions to consider:
#
# - Who are your stakeholders?
# - What are your stakeholders' pain points related to this project?
# - Why are your predictions important from a business perspective?
# - What exactly is your deliverable: your analysis, or the model itself?
# - Does your business understanding/stakeholder require a specific type of model?
#     - For example: a highly regulated industry would require a very transparent/simple/interpretable model, whereas a situation where the model itself is your deliverable would likely benefit from a more complex and thus stronger model
#
#
# Additional questions to consider for classification:
#
# - What does a false positive look like in this context?
# - What does a false negative look like in this context?
# - Which is worse for your stakeholder?
# - What metric are you focusing on optimizing, given the answers to the above questions?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msno

# %%
df = pd.read_csv('../../data/data.csv')
y = pd.read_csv('../../data/status.csv')

# %%
df = df.merge(y,left_on ='id', right_on='id')

# %%
72/255, 31/255, 125/255
# Out:
# (0.2823529411764706, 0.12156862745098039, 0.49019607843137253)

# %%
msno.matrix(df, color=(.28,.12,.49))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-6b9f57093c62> in <module>
# ----> 1 msno.matrix(df, color=(.28,.12,.49)).savefig('missingno.png')
#
# AttributeError: 'AxesSubplot' object has no attribute 'savefig'

# %%
#code to export missingno matrix

fig = msno.matrix(df, color=(.28,.12,.49))
fig_copy = fig.get_figure()
fig_copy.savefig('missingno.png', bbox_inches = 'tight')

# %%
df.describe()
# Out:
#                  id     amount_tsh    gps_height     longitude      latitude  \
# count  59400.000000   59400.000000  59400.000000  59400.000000  5.940000e+04
# mean   37115.131768     317.650385    668.297239     34.077427 -5.706033e+00
# std    21453.128371    2997.574558    693.116350      6.567432  2.946019e+00
# min        0.000000       0.000000    -90.000000      0.000000 -1.164944e+01
# 25%    18519.750000       0.000000      0.000000     33.090347 -8.540621e+00
# 50%    37061.500000       0.000000    369.000000     34.908743 -5.021597e+00
# 75%    55656.500000      20.000000   1319.250000     37.178387 -3.326156e+00
# max    74247.000000  350000.000000   2770.000000     40.345193 -2.000000e-08
#
#         num_private   region_code  district_code    population  \
# count  59400.000000  59400.000000   59400.000000  59400.000000
# mean       0.474141     15.297003       5.629747    179.909983
# std       12.236230     17.587406       9.633649    471.482176
# min        0.000000      1.000000       0.000000      0.000000
# 25%        0.000000      5.000000       2.000000      0.000000
# 50%        0.000000     12.000000       3.000000     25.000000
# 75%        0.000000     17.000000       5.000000    215.000000
# max     1776.000000     99.000000      80.000000  30500.000000
#
#        construction_year
# count       59400.000000
# mean         1300.652475
# std           951.620547
# min             0.000000
# 25%             0.000000
# 50%          1986.000000
# 75%          2004.000000
# max          2013.000000

# %%
df['id'].value_counts(normalize=True).head(50)
# Out:
# 2047     0.000017
# 72310    0.000017
# 49805    0.000017
# 51852    0.000017
# 62091    0.000017
# 64138    0.000017
# 57993    0.000017
# 60040    0.000017
# 33413    0.000017
# 35460    0.000017
# 45699    0.000017
# 41601    0.000017
# 43648    0.000017
# 70263    0.000017
# 68212    0.000017
# 20442    0.000017
# 23134    0.000017
# 19036    0.000017
# 29275    0.000017
# 25177    0.000017
# 27224    0.000017
# 4695     0.000017
# 6742     0.000017
# 597      0.000017
# 2644     0.000017
# 10832    0.000017
# 53839    0.000017
# 55886    0.000017
# 55950    0.000017
# 53903    0.000017
# 10896    0.000017
# 8849     0.000017
# 58057    0.000017
# 60104    0.000017
# 37575    0.000017
# 39622    0.000017
# 33477    0.000017
# 35524    0.000017
# 45763    0.000017
# 47810    0.000017
# 41665    0.000017
# 43712    0.000017
# 70327    0.000017
# 72374    0.000017
# 68276    0.000017
# 21151    0.000017
# 23198    0.000017
# 17053    0.000017
# 29339    0.000017
# 31386    0.000017
# Name: id, dtype: float64

# %%
# subvilage get rid of null value rows
# funder and 
# installer - exclude ppl who have only installed one well - split by % - DON"T '0' INPUT
                       #- private and private individual 
                        # - CUT 
# funder = CUT 
# public meeting  - drop column 
# scheme name drop column 
# scheme_management - fill w/"other"?
# permit - replace with NaN? 
# date_recorded = delete
# lat/long have 1821 missing values (set to 0)

# %%
df['waterpoint_type_group'].unique()[0]
# Out:
# 'communal standpipe'

# %%
for col in df.columns:
    print('Column {} has {} unique values'.format(col, len(df[col].unique())))
    print('Value count: {}'.format(df[col].value_counts()))
# Out:
# Column id has 59400 unique values
# Value count: 2047     1
# 72310    1
# 49805    1
# 51852    1
# 62091    1
#         ..
# 46396    1
# 36155    1
# 34106    1
# 38200    1
# 0        1
# Name: id, Length: 59400, dtype: int64
# Column amount_tsh has 98 unique values
# Value count: 0.0         41639
# 500.0        3102
# 50.0         2472
# 1000.0       1488
# 20.0         1463
#             ...
# 8500.0          1
# 6300.0          1
# 220.0           1
# 138000.0        1
# 12.0            1
# Name: amount_tsh, Length: 98, dtype: int64
# Column date_recorded has 356 unique values
# Value count: 2011-03-15    572
# 2011-03-17    558
# 2013-02-03    546
# 2011-03-14    520
# 2011-03-16    513
#              ...
# 2011-09-19      1
# 2011-09-11      1
# 2011-08-30      1
# 2011-09-06      1
# 2011-09-21      1
# Name: date_recorded, Length: 356, dtype: int64
# Column funder has 1898 unique values
# Value count: Government Of Tanzania    9084
# Danida                    3114
# Hesawa                    2202
# Rwssp                     1374
# World Bank                1349
#                           ...
# Grazie Franco Lucchini       1
# Simon Lusambi                1
# Sent Tho                     1
# Tredsp                       1
# Kdpa                         1
# Name: funder, Length: 1897, dtype: int64
# Column gps_height has 2428 unique values
# Value count:  0       20438
# -15         60
# -16         55
# -13         55
# -20         52
#          ...
#  2285        1
#  2424        1
#  2552        1
#  2413        1
#  2385        1
# Name: gps_height, Length: 2428, dtype: int64
# Column installer has 2146 unique values
# Value count: DWE                               17402
# Government                         1825
# RWE                                1206
# Commu                              1060
# DANIDA                             1050
#                                   ...
# mwakalinga                            1
# Kuji foundation                       1
# Tanzania Egypt Technical Co Op        1
# HESAWQ                                1
# MASWI DRILLING CO. LTD                1
# Name: installer, Length: 2145, dtype: int64
# Column longitude has 57516 unique values
# Value count: 0.000000     1812
# 37.540901       2
# 33.010510       2
# 39.093484       2
# 32.972719       2
#              ...
# 37.579803       1
# 33.196490       1
# 34.017119       1
# 33.788326       1
# 30.163579       1
# Name: longitude, Length: 57516, dtype: int64
# Column latitude has 57517 unique values
# Value count: -2.000000e-08    1812
# -6.985842e+00       2
# -3.797579e+00       2
# -6.981884e+00       2
# -7.104625e+00       2
#                  ...
# -5.726001e+00       1
# -9.646831e+00       1
# -8.124530e+00       1
# -2.535985e+00       1
# -2.598965e+00       1
# Name: latitude, Length: 57517, dtype: int64
# Column wpt_name has 37400 unique values
# Value count: none                      3563
# Shuleni                   1748
# Zahanati                   830
# Msikitini                  535
# Kanisani                   323
#                           ...
# Kwa Mzee Peter Kanneye       1
# Kwa Maheke                   1
# Gidiwili                     1
# Mungudu A                    1
# Uledi                        1
# Name: wpt_name, Length: 37400, dtype: int64
# Column num_private has 65 unique values
# Value count: 0      58643
# 6         81
# 1         73
# 5         46
# 8         46
#        ...
# 180        1
# 213        1
# 23         1
# 55         1
# 94         1
# Name: num_private, Length: 65, dtype: int64
# Column basin has 9 unique values
# Value count: Lake Victoria              10248
# Pangani                     8940
# Rufiji                      7976
# Internal                    7785
# Lake Tanganyika             6432
# Wami / Ruvu                 5987
# Lake Nyasa                  5085
# Ruvuma / Southern Coast     4493
# Lake Rukwa                  2454
# Name: basin, dtype: int64
# Column subvillage has 19288 unique values
# Value count: Madukani            508
# Shuleni             506
# Majengo             502
# Kati                373
# Mtakuja             262
#                    ...
# Rwembilisi            1
# Nyan                  1
# Samanga Kijiweni      1
# Msalalaroad           1
# Kasonkole             1
# Name: subvillage, Length: 19287, dtype: int64
# Column region has 21 unique values
# Value count: Iringa           5294
# Shinyanga        4982
# Mbeya            4639
# Kilimanjaro      4379
# Morogoro         4006
# Arusha           3350
# Kagera           3316
# Mwanza           3102
# Kigoma           2816
# Ruvuma           2640
# Pwani            2635
# Tanga            2547
# Dodoma           2201
# Singida          2093
# Mara             1969
# Tabora           1959
# Rukwa            1808
# Mtwara           1730
# Manyara          1583
# Lindi            1546
# Dar es Salaam     805
# Name: region, dtype: int64
# Column region_code has 27 unique values
# Value count: 11    5300
# 17    5011
# 12    4639
# 3     4379
# 5     4040
# 18    3324
# 19    3047
# 2     3024
# 16    2816
# 10    2640
# 4     2513
# 1     2201
# 13    2093
# 14    1979
# 20    1969
# 15    1808
# 6     1609
# 21    1583
# 80    1238
# 60    1025
# 90     917
# 7      805
# 99     423
# 9      390
# 24     326
# 8      300
# 40       1
# Name: region_code, dtype: int64
# Column district_code has 20 unique values
# Value count: 1     12203
# 2     11173
# 3      9998
# 4      8999
# 5      4356
# 6      4074
# 7      3343
# 8      1043
# 30      995
# 33      874
# 53      745
# 43      505
# 13      391
# 23      293
# 63      195
# 62      109
# 60       63
# 0        23
# 80       12
# 67        6
# Name: district_code, dtype: int64
# Column lga has 125 unique values
# Value count: Njombe          2503
# Arusha Rural    1252
# Moshi Rural     1251
# Bariadi         1177
# Rungwe          1106
#                 ...
# Moshi Urban       79
# Kigoma Urban      71
# Arusha Urban      63
# Lindi Urban       21
# Nyamagana          1
# Name: lga, Length: 125, dtype: int64
# Column ward has 2092 unique values
# Value count: Igosi              307
# Imalinyi           252
# Siha Kati          232
# Mdandu             231
# Nduruma            217
#                   ...
# Mkumbi               1
# Kihangimahuka        1
# Uwanja wa Ndege      1
# Linda                1
# Chinugulu            1
# Name: ward, Length: 2092, dtype: int64
# Column population has 1049 unique values
# Value count: 0       21381
# 1        7025
# 200      1940
# 150      1892
# 250      1681
#         ...
# 3241        1
# 1960        1
# 1685        1
# 2248        1
# 1439        1
# Name: population, Length: 1049, dtype: int64
# Column public_meeting has 3 unique values
# Value count: True     51011
# False     5055
# Name: public_meeting, dtype: int64
# Column recorded_by has 1 unique values
# Value count: GeoData Consultants Ltd    59400
# Name: recorded_by, dtype: int64
# Column scheme_management has 13 unique values
# Value count: VWC                 36793
# WUG                  5206
# Water authority      3153
# WUA                  2883
# Water Board          2748
# Parastatal           1680
# Private operator     1063
# Company              1061
# Other                 766
# SWC                    97
# Trust                  72
# None                    1
# Name: scheme_management, dtype: int64
# Column scheme_name has 2697 unique values
# Value count: K                          682
# None                       644
# Borehole                   546
# Chalinze wate              405
# M                          400
#                           ...
# Namasakata Water Supply      1
# Msjimingi                    1
# PADEP(MIFUGO)                1
# Nabaiye pipe                 1
# Sanire water supply          1
# Name: scheme_name, Length: 2696, dtype: int64
# Column permit has 3 unique values
# Value count: True     38852
# False    17492
# Name: permit, dtype: int64
# Column construction_year has 55 unique values
# Value count: 0       20709
# 2010     2645
# 2008     2613
# 2009     2533
# 2000     2091
# 2007     1587
# 2006     1471
# 2003     1286
# 2011     1256
# 2004     1123
# 2012     1084
# 2002     1075
# 1978     1037
# 1995     1014
# 2005     1011
# 1999      979
# 1998      966
# 1990      954
# 1985      945
# 1980      811
# 1996      811
# 1984      779
# 1982      744
# 1994      738
# 1972      708
# 1974      676
# 1997      644
# 1992      640
# 1993      608
# 2001      540
# 1988      521
# 1983      488
# 1975      437
# 1986      434
# 1976      414
# 1970      411
# 1991      324
# 1989      316
# 1987      302
# 1981      238
# 1977      202
# 1979      192
# 1973      184
# 2013      176
# 1971      145
# 1960      102
# 1967       88
# 1963       85
# 1968       77
# 1969       59
# 1964       40
# 1962       30
# 1961       21
# 1965       19
# 1966       17
# Name: construction_year, dtype: int64
# Column extraction_type has 18 unique values
# Value count: gravity                      26780
# nira/tanira                   8154
# other                         6430
# submersible                   4764
# swn 80                        3670
# mono                          2865
# india mark ii                 2400
# afridev                       1770
# ksb                           1415
# other - rope pump              451
# other - swn 81                 229
# windmill                       117
# india mark iii                  98
# cemo                            90
# other - play pump               85
# walimi                          48
# climax                          32
# other - mkulima/shinyanga        2
# Name: extraction_type, dtype: int64
# Column extraction_type_group has 13 unique values
# Value count: gravity            26780
# nira/tanira         8154
# other               6430
# submersible         6179
# swn 80              3670
# mono                2865
# india mark ii       2400
# afridev             1770
# rope pump            451
# other handpump       364
# other motorpump      122
# wind-powered         117
# india mark iii        98
# Name: extraction_type_group, dtype: int64
# Column extraction_type_class has 7 unique values
# Value count: gravity         26780
# handpump        16456
# other            6430
# submersible      6179
# motorpump        2987
# rope pump         451
# wind-powered      117
# Name: extraction_type_class, dtype: int64
# Column management has 12 unique values
# Value count: vwc                 40507
# wug                  6515
# water board          2933
# wua                  2535
# private operator     1971
# parastatal           1768
# water authority       904
# other                 844
# company               685
# unknown               561
# other - school         99
# trust                  78
# Name: management, dtype: int64
# Column management_group has 5 unique values
# Value count: user-group    52490
# commercial     3638
# parastatal     1768
# other           943
# unknown         561
# Name: management_group, dtype: int64
# Column payment has 7 unique values
# Value count: never pay                25348
# pay per bucket            8985
# pay monthly               8300
# unknown                   8157
# pay when scheme fails     3914
# pay annually              3642
# other                     1054
# Name: payment, dtype: int64
# Column payment_type has 7 unique values
# Value count: never pay     25348
# per bucket     8985
# monthly        8300
# unknown        8157
# on failure     3914
# annually       3642
# other          1054
# Name: payment_type, dtype: int64
# Column water_quality has 8 unique values
# Value count: soft                  50818
# salty                  4856
# unknown                1876
# milky                   804
# coloured                490
# salty abandoned         339
# fluoride                200
# fluoride abandoned       17
# Name: water_quality, dtype: int64
# Column quality_group has 6 unique values
# Value count: good        50818
# salty        5195
# unknown      1876
# milky         804
# colored       490
# fluoride      217
# Name: quality_group, dtype: int64
# Column quantity has 5 unique values
# Value count: enough          33186
# insufficient    15129
# dry              6246
# seasonal         4050
# unknown           789
# Name: quantity, dtype: int64
# Column quantity_group has 5 unique values
# Value count: enough          33186
# insufficient    15129
# dry              6246
# seasonal         4050
# unknown           789
# Name: quantity_group, dtype: int64
# Column source has 10 unique values
# Value count: spring                  17021
# shallow well            16824
# machine dbh             11075
# river                    9612
# rainwater harvesting     2295
# hand dtw                  874
# lake                      765
# dam                       656
# other                     212
# unknown                    66
# Name: source, dtype: int64
# Column source_type has 7 unique values
# Value count: spring                  17021
# shallow well            16824
# borehole                11949
# river/lake              10377
# rainwater harvesting     2295
# dam                       656
# other                     278
# Name: source_type, dtype: int64
# Column source_class has 3 unique values
# Value count: groundwater    45794
# surface        13328
# unknown          278
# Name: source_class, dtype: int64
# Column waterpoint_type has 7 unique values
# Value count: communal standpipe             28522
# hand pump                      17488
# other                           6380
# communal standpipe multiple     6103
# improved spring                  784
# cattle trough                    116
# dam                                7
# Name: waterpoint_type, dtype: int64
# Column waterpoint_type_group has 6 unique values
# Value count: communal standpipe    34625
# hand pump             17488
# other                  6380
# improved spring         784
# cattle trough           116
# dam                       7
# Name: waterpoint_type_group, dtype: int64
# Column status_group has 3 unique values
# Value count: functional                 32259
# non functional             22824
# functional needs repair     4317
# Name: status_group, dtype: int64

# %% [markdown]
# ## Data Understanding
#
# Describe the data being used for this project.
#
# Questions to consider:
#
# - Where did the data come from, and how do they relate to the data analysis questions?
# - What do the data represent? Who is in the sample and what variables are included?
# - What is the target variable?
# - What are the properties of the variables you intend to use?

# %%
# code here to explore your data

# %% [markdown]
# ## Data Preparation
#
# Describe and justify the process for preparing the data for analysis.
#
# Questions to consider:
#
# - Were there variables you dropped or created?
# - How did you address missing values or outliers?
# - Why are these choices appropriate given the data and the business problem?
# - Can you pipeline your preparation steps to use them consistently in the modeling process?

# %%
# code here to prepare your data

# %% [markdown]
# ## Modeling
#
# Describe and justify the process for analyzing or modeling the data.
#
# Questions to consider:
#
# - How will you analyze the data to arrive at an initial approach?
# - How will you iterate on your initial approach to make it better?
# - What model type is most appropriate, given the data and the business problem?

# %% [markdown]
# ## Evaluation
#
# The evaluation of each model should accompany the creation of each model, and you should be sure to evaluate your models consistently.
#
# Evaluate how well your work solves the stated business problem.
#
# Questions to consider:
#
# - How do you interpret the results?
# - How well does your model fit your data? How much better is this than your baseline model? Is it over or under fit?
# - How well does your model/data fit any relevant modeling assumptions?
#
# For the final model, you might also consider:
#
# - How confident are you that your results would generalize beyond the data you have?
# - How confident are you that this model would benefit the business if put into use?
# - What does this final model tell you about the relationship between your inputs and outputs?

# %% [markdown]
# ### Baseline Understanding
#
# - What does a baseline, model-less prediction look like?

# %%
# code here to arrive at a baseline prediction

# %% [markdown]
# ### First $&(@# Model
#
# Before going too far down the data preparation rabbit hole, be sure to check your work against a first 'substandard' model! What is the easiest way for you to find out how hard your problem is?

# %%
# code here for your first 'substandard' model

# %%
# code here to evaluate your first 'substandard' model

# %% [markdown]
# ### Modeling Iterations
#
# Now you can start to use the results of your first model to iterate - there are many options!

# %%
# code here to iteratively improve your models

# %%
# code here to evaluate your iterations

# %% [markdown]
# ### 'Final' Model
#
# In the end, you'll arrive at a 'final' model - aka the one you'll use to make your recommendations/conclusions. This likely blends any group work. It might not be the one with the highest scores, but instead might be considered 'final' or 'best' for other reasons.

# %%
# code here to show your final model

# %%
# code here to evaluate your final model

# %% [markdown]
# ## Conclusions
#
# Provide your conclusions about the work you've done, including any limitations or next steps.
#
# Questions to consider:
#
# - What would you recommend the business do as a result of this work?
# - How could the stakeholder use your model effectively?
# - What are some reasons why your analysis might not fully solve the business problem?
# - What else could you do in the future to improve this project (future work)?
