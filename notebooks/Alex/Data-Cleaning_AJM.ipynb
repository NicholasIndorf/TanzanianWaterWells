# %% [markdown]
# # Tanzanian Water Wells

# %%
import numpy as np
import pandas as pd
# settings to display all columns
pd.set_option("display.max_columns", None)
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Project Overview
#
# Our group has been hired by Tanzania's Ministry of Water to develop a classification model that will assist Tanzania's Ministry of Water in predicting the status of the waterpoints they oversee. Although the waterpoint statuses could be described in a number of ways - e.g. whether it is functional but needs repair - our model will perform a binary classification to determine if the waterpoint is functioning as exepected or not.
#
# ## Business Problem
#
# While the country of Tanzania has numerous aquifiers including Lake Victoria, the largest lake in Africa, nearly 50% of the waterpoints overseen by the Ministry of Water are non-functional, leaving large segments of the population without a reliable or potable source of water. The model needed to take into consideration the fact that if wells were incorrectly identified as being functional then communities would be left without water, and conversely if the model identified working wells as broken the Ministry would not be able to allocate their res

# %% [markdown]
# **Note:** 'well', 'pump', 'watersource', etc. etc. are all used interchangeably to refer to the target, which is its function status

# %%
# import well status and data information
status = pd.read_csv('../../data/status.csv', index_col='id')
data = pd.read_csv('../../data/data.csv', index_col='id')

# %%
# merge both on pump id
df = pd.merge(status, data, on='id')

# %%
# drop duplicates
df.drop_duplicates(inplace=True)
df.head()
# Out:
#          status_group  amount_tsh date_recorded        funder  gps_height  \
# id
# 69572      functional      6000.0    2011-03-14         Roman        1390
# 8776       functional         0.0    2013-03-06       Grumeti        1399
# 34310      functional        25.0    2013-02-25  Lottery Club         686
# 67743  non functional         0.0    2013-01-28        Unicef         263
# 19728      functional         0.0    2011-07-13   Action In A           0
#
#           installer  longitude   latitude              wpt_name  num_private  \
# id
# 69572         Roman  34.938093  -9.856322                  none            0
# 8776        GRUMETI  34.698766  -2.147466              Zahanati            0
# 34310  World vision  37.460664  -3.821329           Kwa Mahundi            0
# 67743        UNICEF  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 19728       Artisan  31.130847  -1.825359               Shuleni            0
#
#                          basin  subvillage   region  region_code  \
# id
# 69572               Lake Nyasa    Mnyusi B   Iringa           11
# 8776             Lake Victoria     Nyamara     Mara           20
# 34310                  Pangani     Majengo  Manyara           21
# 67743  Ruvuma / Southern Coast  Mahakamani   Mtwara           90
# 19728            Lake Victoria  Kyanyamisa   Kagera           18
#
#        district_code        lga        ward  population public_meeting  \
# id
# 69572              5     Ludewa    Mundindi         109           True
# 8776               2  Serengeti       Natta         280            NaN
# 34310              4  Simanjiro     Ngorika         250           True
# 67743             63   Nanyumbu    Nanyumbu          58           True
# 19728              1    Karagwe  Nyakasimbi           0           True
#
#                    recorded_by scheme_management                  scheme_name  \
# id
# 69572  GeoData Consultants Ltd               VWC                        Roman
# 8776   GeoData Consultants Ltd             Other                          NaN
# 34310  GeoData Consultants Ltd               VWC  Nyumba ya mungu pipe scheme
# 67743  GeoData Consultants Ltd               VWC                          NaN
# 19728  GeoData Consultants Ltd               NaN                          NaN
#
#       permit  construction_year extraction_type extraction_type_group  \
# id
# 69572  False               1999         gravity               gravity
# 8776    True               2010         gravity               gravity
# 34310   True               2009         gravity               gravity
# 67743   True               1986     submersible           submersible
# 19728   True                  0         gravity               gravity
#
#       extraction_type_class management management_group         payment  \
# id
# 69572               gravity        vwc       user-group    pay annually
# 8776                gravity        wug       user-group       never pay
# 34310               gravity        vwc       user-group  pay per bucket
# 67743           submersible        vwc       user-group       never pay
# 19728               gravity      other            other       never pay
#
#       payment_type water_quality quality_group      quantity quantity_group  \
# id
# 69572     annually          soft          good        enough         enough
# 8776     never pay          soft          good  insufficient   insufficient
# 34310   per bucket          soft          good        enough         enough
# 67743    never pay          soft          good           dry            dry
# 19728    never pay          soft          good      seasonal       seasonal
#
#                      source           source_type source_class  \
# id
# 69572                spring                spring  groundwater
# 8776   rainwater harvesting  rainwater harvesting      surface
# 34310                   dam                   dam      surface
# 67743           machine dbh              borehole  groundwater
# 19728  rainwater harvesting  rainwater harvesting      surface
#
#                    waterpoint_type waterpoint_type_group
# id
# 69572           communal standpipe    communal standpipe
# 8776            communal standpipe    communal standpipe
# 34310  communal standpipe multiple    communal standpipe
# 67743  communal standpipe multiple    communal standpipe
# 19728           communal standpipe    communal standpipe

# %%
# status counts
df['status_group'].value_counts()
# Out:
# functional                 32237
# non functional             22813
# functional needs repair     4314
# Name: status_group, dtype: int64

# %%
# visualize
sns.barplot(x=df['status_group'].value_counts().index, y=df['status_group'].value_counts())
# Out:
# <AxesSubplot:ylabel='status_group'>

# %% [markdown]
# Based on the breakdown of the groups, we decided to turn our status column into a binary to make our classification process more straightforward.
#
# The 'functional needs repair' classification will be grouped in with the non-functional classification. The idea being, maintenance and repair will still be valuable on a damagaged waterpoint. It makes sense for our stakeholder to include in damaged waterpoints with this group because they are looking for where to direct their attention. It would be much mroe costly to the people of the area for a damaged waterpoint to be classified as completely functional and not get any additinal attention.

# %%
# combine 'functional needs repair' into 'non functional'
df.loc[df['status_group'] == 'functional needs repair', 'status_group'] = 'non functional'

# %% [markdown]
# After our status combination, our split shows a much more balanced distribution of our data.

# %%
# Visualizing our breakdown

fig, ax = plt.subplots()
plt.style.use('seaborn-talk')
sns.barplot(x=df['status_group'].value_counts().index, y=df['status_group'].value_counts())
ax.set_title('Waterpoint Functionality Breakdown')
ax.set_xlabel('Functional vs. Non-Functional')
ax.set_ylabel('Waterpoint #')
# Out:
# Text(0, 0.5, 'Waterpoint #')

# %% [markdown]
# We can now start diving into our numerical and categorical columns, as well as looking for null values and other problematic values in the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59364 entries, 69572 to 26348
# Data columns (total 40 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   status_group           59364 non-null  object
#  1   amount_tsh             59364 non-null  float64
#  2   date_recorded          59364 non-null  object
#  3   funder                 55729 non-null  object
#  4   gps_height             59364 non-null  int64
#  5   installer              55709 non-null  object
#  6   longitude              59364 non-null  float64
#  7   latitude               59364 non-null  float64
#  8   wpt_name               59364 non-null  object
#  9   num_private            59364 non-null  int64
#  10  basin                  59364 non-null  object
#  11  subvillage             58993 non-null  object
#  12  region                 59364 non-null  object
#  13  region_code            59364 non-null  int64
#  14  district_code          59364 non-null  int64
#  15  lga                    59364 non-null  object
#  16  ward                   59364 non-null  object
#  17  population             59364 non-null  int64
#  18  public_meeting         56050 non-null  object
#  19  recorded_by            59364 non-null  object
#  20  scheme_management      55487 non-null  object
#  21  scheme_name            31225 non-null  object
#  22  permit                 56308 non-null  object
#  23  construction_year      59364 non-null  int64
#  24  extraction_type        59364 non-null  object
#  25  extraction_type_group  59364 non-null  object
#  26  extraction_type_class  59364 non-null  object
#  27  management             59364 non-null  object
#  28  management_group       59364 non-null  object
#  29  payment                59364 non-null  object
#  30  payment_type           59364 non-null  object
#  31  water_quality          59364 non-null  object
#  32  quality_group          59364 non-null  object
#  33  quantity               59364 non-null  object
#  34  quantity_group         59364 non-null  object
#  35  source                 59364 non-null  object
#  36  source_type            59364 non-null  object
#  37  source_class           59364 non-null  object
#  38  waterpoint_type        59364 non-null  object
#  39  waterpoint_type_group  59364 non-null  object
# dtypes: float64(3), int64(6), object(31)
# memory usage: 18.6+ MB

# %%
df.describe()
# Out:
#           amount_tsh    gps_height     longitude      latitude   num_private  \
# count   59364.000000  59364.000000  59364.000000  5.936400e+04  59364.000000
# mean      317.843017    668.702513     34.097560 -5.709463e+00      0.474429
# std      2998.473133    693.131013      6.517065  2.943608e+00     12.239934
# min         0.000000    -90.000000      0.000000 -1.164944e+01      0.000000
# 25%         0.000000      0.000000     33.095187 -8.541904e+00      0.000000
# 50%         0.000000    370.000000     34.910318 -5.023822e+00      0.000000
# 75%        20.000000   1320.000000     37.179490 -3.326918e+00      0.000000
# max    350000.000000   2770.000000     40.345193 -2.000000e-08   1776.000000
#
#         region_code  district_code    population  construction_year
# count  59364.000000   59364.000000  59364.000000       59364.000000
# mean      15.295516       5.631494    180.019086        1301.441227
# std       17.592619       9.636138    471.604294         951.369704
# min        1.000000       0.000000      0.000000           0.000000
# 25%        5.000000       2.000000      0.000000           0.000000
# 50%       12.000000       3.000000     25.000000        1986.000000
# 75%       17.000000       5.000000    215.000000        2004.000000
# max       99.000000      80.000000  30500.000000        2013.000000

# %%
# separate into numerical and categorical features
cat_cols = []
num_cols = []
for col in df.columns:
    if df[col].dtype in ['object']:
        cat_cols.append(col)
    else:
        num_cols.append(col)

# %%
# visualize numericals
fig, axes = plt.subplots(nrows=len(num_cols),figsize=(20,30))
plt.tight_layout()
for i, col in enumerate(num_cols):
    sns.histplot(df[col], bins=50, ax=axes[i])

# %% [markdown]
# **Initial Numerical Column Impressions**
#
# Very little of our numerical data can be classified as having a normal distribution. Because of this, we will avoid using a StandardScaler. We can see problems in our longitude data as it is not possible for there to be a longitude of 0 in Tanzania. We also see that there is a large proportion of 0 values in population and construction year that we will address later.
#
# It doesn't matter that `amount_tsh` has a large propportion of 0s. The data dictionary describes it as "amount_tsh - Total static head (amount water available to waterpoint)". This might seem quite bad, because this makes it sound like the total water available is 0 for over 70% of water points. However, this is an incorrect description for Total Static Head, as shown [here](../../notebooks/Nick/images/total_static_head.jpeg). It's simply the distance from the surface of the source to the surface of the access point, so actually having '0' is a good thing.

# %%
(df['longitude'] == 0).sum()
# Out:
# 1777

# %%
(df['latitude'] == 0).sum()
# Out:
# 0

# %%
df[df['longitude'] == 0]['latitude'].value_counts()
# Out:
# -2.000000e-08    1777
# Name: latitude, dtype: int64

# %%
# transform incorrect long/lat to nulls 
df.loc[(df['longitude']== 0), ('longitude','latitude')] = np.nan

# %%
# transform construction year 0 to nulls
df.loc[(df['construction_year']== 0), 'construction_year'] = np.nan

# %%
# percent 0 in each column
(df == 0).sum(axis=0)/len(data)*100
# Out:
# status_group              0.000000
# amount_tsh               70.038721
# date_recorded             0.000000
# funder                    0.000000
# gps_height               34.346801
# installer                 0.000000
# longitude                 0.000000
# latitude                  0.000000
# wpt_name                  0.000000
# num_private              98.664983
# basin                     0.000000
# subvillage                0.000000
# region                    0.000000
# region_code               0.000000
# district_code             0.038721
# lga                       0.000000
# ward                      0.000000
# population               35.934343
# public_meeting            8.508418
# recorded_by               0.000000
# scheme_management         0.000000
# scheme_name               0.000000
# permit                   29.410774
# construction_year         0.000000
# extraction_type           0.000000
# extraction_type_group     0.000000
# extraction_type_class     0.000000
# management                0.000000
# management_group          0.000000
# payment                   0.000000
# payment_type              0.000000
# water_quality             0.000000
# quality_group             0.000000
# quantity                  0.000000
# quantity_group            0.000000
# source                    0.000000
# source_type               0.000000
# source_class              0.000000
# waterpoint_type           0.000000
# waterpoint_type_group     0.000000
# dtype: float64

# %%
# check out upper tail of amount_tsh
df['amount_tsh'].sort_values(ascending=False).head(30)
# Out:
# id
# 41564    350000.0
# 4128     250000.0
# 7860     200000.0
# 70107    170000.0
# 54154    138000.0
# 15191    120000.0
# 71707    117000.0
# 15801    117000.0
# 64148    117000.0
# 38117    117000.0
# 18724    117000.0
# 7737     117000.0
# 4712     117000.0
# 45188    100000.0
# 10996    100000.0
# 69674    100000.0
# 65614     70000.0
# 58336     60000.0
# 24876     50000.0
# 13946     50000.0
# 35268     50000.0
# 3252      50000.0
# 73818     45000.0
# 28057     45000.0
# 30855     45000.0
# 40048     40000.0
# 73094     40000.0
# 28620     40000.0
# 48346     40000.0
# 50998     40000.0
# Name: amount_tsh, dtype: float64

# %% [markdown]
# Although it is not indicated in our data description, we assume that the population is being measured in units of 100.

# %%
df.isna().sum().sum()
# Out:
# 24227

# %%
# check out upper tail of population
df['population'].sort_values(ascending=False).head(30)
# Out:
# id
# 12169    30500
# 49354    15300
# 30750    11463
# 21166    10000
# 63349    10000
# 56570    10000
# 33117     9865
# 18520     9500
# 16664     9000
# 69166     9000
# 17459     9000
# 72820     8848
# 2118      8600
# 42967     8500
# 41994     8200
# 42627     8000
# 64021     8000
# 6280      8000
# 36272     8000
# 61539     8000
# 11002     7530
# 13182     7500
# 60098     7500
# 11571     7500
# 9941      7000
# 15841     7000
# 29054     6922
# 19042     6922
# 50707     6922
# 55230     6922
# Name: population, dtype: int64

# %%
# percent null in each column
df.isna().sum()/len(data)*100
# Out:
# status_group              0.000000
# amount_tsh                0.000000
# date_recorded             0.000000
# funder                    6.119529
# gps_height                0.000000
# installer                 6.153199
# longitude                 2.991582
# latitude                  2.991582
# wpt_name                  0.000000
# num_private               0.000000
# basin                     0.000000
# subvillage                0.624579
# region                    0.000000
# region_code               0.000000
# district_code             0.000000
# lga                       0.000000
# ward                      0.000000
# population                0.000000
# public_meeting            5.579125
# recorded_by               0.000000
# scheme_management         6.526936
# scheme_name              47.372054
# permit                    5.144781
# construction_year        34.803030
# extraction_type           0.000000
# extraction_type_group     0.000000
# extraction_type_class     0.000000
# management                0.000000
# management_group          0.000000
# payment                   0.000000
# payment_type              0.000000
# water_quality             0.000000
# quality_group             0.000000
# quantity                  0.000000
# quantity_group            0.000000
# source                    0.000000
# source_type               0.000000
# source_class              0.000000
# waterpoint_type           0.000000
# waterpoint_type_group     0.000000
# dtype: float64

# %%
#Looking through the characteristics of unique values in our columns as well as the number of unique values in each column
for col in df.columns:
    print(f'{col}:')
    print(df[col].value_counts(normalize=True))
    print(df[col].nunique())
    print('<>'*5)
# Out:
# status_group:
# functional        0.54304
# non functional    0.45696
# Name: status_group, dtype: float64
# 2
# <><><><><>
# amount_tsh:
# 0.0         0.700812
# 500.0       0.052254
# 50.0        0.041641
# 1000.0      0.025066
# 20.0        0.024645
#               ...
# 8500.0      0.000017
# 6300.0      0.000017
# 220.0       0.000017
# 138000.0    0.000017
# 12.0        0.000017
# Name: amount_tsh, Length: 98, dtype: float64
# 98
# <><><><><>
# date_recorded:
# 2011-03-15    0.009635
# 2011-03-17    0.009400
# 2013-02-03    0.009197
# 2011-03-14    0.008760
# 2011-03-16    0.008642
#                 ...
# 2011-09-26    0.000017
# 2011-09-23    0.000017
# 2011-09-13    0.000017
# 2011-09-06    0.000017
# 2011-09-16    0.000017
# Name: date_recorded, Length: 356, dtype: float64
# 356
# <><><><><>
# funder:
# Government Of Tanzania          0.162860
# Danida                          0.055878
# Hesawa                          0.039441
# Rwssp                           0.024619
# World Bank                      0.024206
#                                   ...
# Cristan Outrich                 0.000018
# Babtist                         0.000018
# Tajiri Jumbe Lila               0.000018
# Village Council/ Rose Kawala    0.000018
# Pag Church                      0.000018
# Name: funder, Length: 1897, dtype: float64
# 1897
# <><><><><>
# gps_height:
#  0       0.343676
# -15      0.001011
# -16      0.000926
# -13      0.000926
# -20      0.000876
#            ...
#  2285    0.000017
#  2424    0.000017
#  2552    0.000017
#  2413    0.000017
#  2385    0.000017
# Name: gps_height, Length: 2428, dtype: float64
# 2428
# <><><><><>
# installer:
# DWE                0.312068
# Government         0.032634
# RWE                0.021630
# Commu              0.019027
# DANIDA             0.018848
#                      ...
# ABD                0.000018
# Mkuluku            0.000018
# VWT                0.000018
# TMP                0.000018
# Mohamad Masanga    0.000018
# Name: installer, Length: 2145, dtype: float64
# 2145
# <><><><><>
# longitude:
# 39.090448    0.000035
# 39.086287    0.000035
# 39.086183    0.000035
# 39.098514    0.000035
# 39.093095    0.000035
#                ...
# 37.579803    0.000017
# 33.196490    0.000017
# 34.017119    0.000017
# 33.788326    0.000017
# 35.005922    0.000017
# Name: longitude, Length: 57515, dtype: float64
# 57515
# <><><><><>
# latitude:
# -6.963565    0.000035
# -2.506590    0.000035
# -7.104625    0.000035
# -7.175174    0.000035
# -6.964258    0.000035
#                ...
# -5.726001    0.000017
# -9.646831    0.000017
# -8.124530    0.000017
# -2.535985    0.000017
# -2.598965    0.000017
# Name: latitude, Length: 57516, dtype: float64
# 57516
# <><><><><>
# wpt_name:
# none                   0.059986
# Shuleni                0.029445
# Zahanati               0.013982
# Msikitini              0.009012
# Kanisani               0.005441
#                          ...
# Kwa Mzee Mwanyusi      0.000017
# Kwa Chilumba Jabiri    0.000017
# Kwa Matata Ibrahim     0.000017
# Kwa Ruziro             0.000017
# Kwa Lulu               0.000017
# Name: wpt_name, Length: 37400, dtype: float64
# 37400
# <><><><><>
# num_private:
# 0      0.987248
# 6      0.001364
# 1      0.001230
# 5      0.000775
# 8      0.000775
#          ...
# 180    0.000017
# 213    0.000017
# 23     0.000017
# 55     0.000017
# 94     0.000017
# Name: num_private, Length: 65, dtype: float64
# 65
# <><><><><>
# basin:
# Lake Victoria              0.172023
# Pangani                    0.150596
# Rufiji                     0.134358
# Internal                   0.131140
# Lake Tanganyika            0.108348
# Wami / Ruvu                0.100852
# Lake Nyasa                 0.085658
# Ruvuma / Southern Coast    0.075686
# Lake Rukwa                 0.041338
# Name: basin, dtype: float64
# 9
# <><><><><>
# subvillage:
# Shuleni            0.008560
# Madukani           0.008526
# Majengo            0.008509
# Kati               0.006323
# Mtakuja            0.004441
#                      ...
# Mtonya B           0.000017
# Mushule            0.000017
# Kafwandi           0.000017
# Nationanal Park    0.000017
# Mwilongalage B     0.000017
# Name: subvillage, Length: 19287, dtype: float64
# 19287
# <><><><><>
# region:
# Iringa           0.089179
# Shinyanga        0.083889
# Mbeya            0.078145
# Kilimanjaro      0.073765
# Morogoro         0.067482
# Arusha           0.056432
# Kagera           0.055842
# Mwanza           0.051698
# Kigoma           0.047436
# Ruvuma           0.044471
# Pwani            0.044387
# Tanga            0.042905
# Dodoma           0.037076
# Singida          0.035257
# Mara             0.033168
# Tabora           0.033000
# Rukwa            0.030456
# Mtwara           0.029142
# Manyara          0.026666
# Lindi            0.026043
# Dar es Salaam    0.013560
# Name: region, dtype: float64
# 21
# <><><><><>
# region_code:
# 11    0.089280
# 17    0.084041
# 12    0.078145
# 3     0.073765
# 5     0.068055
# 18    0.055977
# 19    0.051108
# 2     0.050940
# 16    0.047436
# 10    0.044471
# 4     0.042332
# 1     0.037076
# 13    0.035257
# 14    0.033337
# 20    0.033168
# 15    0.030456
# 6     0.027104
# 21    0.026666
# 80    0.020854
# 60    0.017266
# 90    0.015447
# 7     0.013560
# 99    0.007126
# 9     0.006570
# 24    0.005492
# 8     0.005054
# 40    0.000017
# Name: region_code, dtype: float64
# 27
# <><><><><>
# district_code:
# 1     0.205192
# 2     0.188195
# 3     0.168402
# 4     0.151590
# 5     0.073378
# 6     0.068425
# 7     0.056314
# 8     0.017570
# 30    0.016761
# 33    0.014723
# 53    0.012550
# 43    0.008507
# 13    0.006586
# 23    0.004936
# 63    0.003285
# 62    0.001836
# 60    0.001061
# 0     0.000387
# 80    0.000202
# 67    0.000101
# Name: district_code, dtype: float64
# 20
# <><><><><>
# lga:
# Njombe          0.042164
# Arusha Rural    0.021090
# Moshi Rural     0.021073
# Bariadi         0.019793
# Rungwe          0.018631
#                   ...
# Moshi Urban     0.001331
# Kigoma Urban    0.001196
# Arusha Urban    0.001061
# Lindi Urban     0.000354
# Nyamagana       0.000017
# Name: lga, Length: 125, dtype: float64
# 125
# <><><><><>
# ward:
# Igosi            0.005171
# Imalinyi         0.004245
# Siha Kati        0.003908
# Mdandu           0.003891
# Nduruma          0.003655
#                    ...
# Chinugulu        0.000017
# Kirongo          0.000017
# Ukata            0.000017
# Kihangimahuka    0.000017
# Mitole           0.000017
# Name: ward, Length: 2092, dtype: float64
# 2092
# <><><><><>
# population:
# 0       0.359561
# 1       0.118338
# 200     0.032680
# 150     0.031871
# 250     0.028317
#           ...
# 3241    0.000017
# 1960    0.000017
# 1685    0.000017
# 2248    0.000017
# 1439    0.000017
# Name: population, Length: 1049, dtype: float64
# 1049
# <><><><><>
# public_meeting:
# True     0.909831
# False    0.090169
# Name: public_meeting, dtype: float64
# 2
# <><><><><>
# recorded_by:
# GeoData Consultants Ltd    1.0
# Name: recorded_by, dtype: float64
# 1
# <><><><><>
# scheme_management:
# VWC                 0.662840
# WUG                 0.093463
# Water authority     0.056824
# WUA                 0.051958
# Water Board         0.049525
# Parastatal          0.030241
# Private operator    0.019158
# Company             0.019122
# Other               0.013805
# SWC                 0.001748
# Trust               0.001298
# None                0.000018
# Name: scheme_management, dtype: float64
# 12
# <><><><><>
# scheme_name:
# K                                 0.021841
# None                              0.020624
# Borehole                          0.017454
# Chalinze wate                     0.012970
# M                                 0.012810
#                                     ...
# Mkunya                            0.000032
# Losaa kia gravity water supply    0.000032
# Kima                              0.000032
# Miga                              0.000032
# BL Kyongwa                        0.000032
# Name: scheme_name, Length: 2696, dtype: float64
# 2696
# <><><><><>
# permit:
# True     0.689742
# False    0.310258
# Name: permit, dtype: float64
# 2
# <><><><><>
# construction_year:
# 2010.0    0.068362
# 2008.0    0.067535
# 2009.0    0.065467
# 2000.0    0.054044
# 2007.0    0.041017
# 2006.0    0.038019
# 2003.0    0.033238
# 2011.0    0.032462
# 2004.0    0.029025
# 2012.0    0.028017
# 2002.0    0.027784
# 1978.0    0.026802
# 1995.0    0.026208
# 2005.0    0.026130
# 1999.0    0.025303
# 1998.0    0.024967
# 1990.0    0.024657
# 1985.0    0.024424
# 1996.0    0.020961
# 1980.0    0.020961
# 1984.0    0.020134
# 1982.0    0.019229
# 1994.0    0.019074
# 1972.0    0.018299
# 1974.0    0.017472
# 1997.0    0.016645
# 1992.0    0.016541
# 1993.0    0.015714
# 2001.0    0.013957
# 1988.0    0.013466
# 1983.0    0.012613
# 1975.0    0.011295
# 1986.0    0.011217
# 1976.0    0.010700
# 1970.0    0.010623
# 1991.0    0.008374
# 1989.0    0.008167
# 1987.0    0.007805
# 1981.0    0.006151
# 1977.0    0.005221
# 1979.0    0.004962
# 1973.0    0.004756
# 2013.0    0.004549
# 1971.0    0.003748
# 1960.0    0.002636
# 1967.0    0.002274
# 1963.0    0.002197
# 1968.0    0.001990
# 1969.0    0.001525
# 1964.0    0.001034
# 1962.0    0.000775
# 1961.0    0.000543
# 1965.0    0.000491
# 1966.0    0.000439
# Name: construction_year, dtype: float64
# 54
# <><><><><>
# extraction_type:
# gravity                      0.451048
# nira/tanira                  0.137171
# other                        0.108264
# submersible                  0.080166
# swn 80                       0.061704
# mono                         0.048262
# india mark ii                0.040395
# afridev                      0.029799
# ksb                          0.023802
# other - rope pump            0.007597
# other - swn 81               0.003858
# windmill                     0.001971
# india mark iii               0.001634
# cemo                         0.001516
# other - play pump            0.001432
# walimi                       0.000809
# climax                       0.000539
# other - mkulima/shinyanga    0.000034
# Name: extraction_type, dtype: float64
# 18
# <><><><><>
# extraction_type_group:
# gravity            0.451048
# nira/tanira        0.137171
# other              0.108264
# submersible        0.103969
# swn 80             0.061704
# mono               0.048262
# india mark ii      0.040395
# afridev            0.029799
# rope pump          0.007597
# other handpump     0.006132
# other motorpump    0.002055
# wind-powered       0.001971
# india mark iii     0.001634
# Name: extraction_type_group, dtype: float64
# 13
# <><><><><>
# extraction_type_class:
# gravity         0.451048
# handpump        0.276834
# other           0.108264
# submersible     0.103969
# motorpump       0.050317
# rope pump       0.007597
# wind-powered    0.001971
# Name: extraction_type_class, dtype: float64
# 7
# <><><><><>
# management:
# vwc                 0.682114
# wug                 0.109410
# water board         0.049407
# wua                 0.042703
# private operator    0.033202
# parastatal          0.029749
# water authority     0.015228
# other               0.014217
# company             0.011539
# unknown             0.009450
# other - school      0.001668
# trust               0.001314
# Name: management, dtype: float64
# 12
# <><><><><>
# management_group:
# user-group    0.883633
# commercial    0.061283
# parastatal    0.029749
# other         0.015885
# unknown       0.009450
# Name: management_group, dtype: float64
# 5
# <><><><><>
# payment:
# never pay                0.426807
# pay per bucket           0.151338
# pay monthly              0.139815
# unknown                  0.137019
# pay when scheme fails    0.065932
# pay annually             0.061350
# other                    0.017738
# Name: payment, dtype: float64
# 7
# <><><><><>
# payment_type:
# never pay     0.426807
# per bucket    0.151338
# monthly       0.139815
# unknown       0.137019
# on failure    0.065932
# annually      0.061350
# other         0.017738
# Name: payment_type, dtype: float64
# 7
# <><><><><>
# water_quality:
# soft                  0.855485
# salty                 0.081800
# unknown               0.031551
# milky                 0.013544
# coloured              0.008254
# salty abandoned       0.005711
# fluoride              0.003369
# fluoride abandoned    0.000286
# Name: water_quality, dtype: float64
# 8
# <><><><><>
# quality_group:
# good        0.855485
# salty       0.087511
# unknown     0.031551
# milky       0.013544
# colored     0.008254
# fluoride    0.003655
# Name: quality_group, dtype: float64
# 6
# <><><><><>
# quantity:
# enough          0.558672
# insufficient    0.254683
# dry             0.105165
# seasonal        0.068189
# unknown         0.013291
# Name: quantity, dtype: float64
# 5
# <><><><><>
# quantity_group:
# enough          0.558672
# insufficient    0.254683
# dry             0.105165
# seasonal        0.068189
# unknown         0.013291
# Name: quantity_group, dtype: float64
# 5
# <><><><><>
# source:
# spring                  0.286706
# shallow well            0.283017
# machine dbh             0.186460
# river                   0.161916
# rainwater harvesting    0.038626
# hand dtw                0.014723
# lake                    0.012853
# dam                     0.011034
# other                   0.003554
# unknown                 0.001112
# Name: source, dtype: float64
# 10
# <><><><><>
# source_type:
# spring                  0.286706
# shallow well            0.283017
# borehole                0.201183
# river/lake              0.174769
# rainwater harvesting    0.038626
# dam                     0.011034
# other                   0.004666
# Name: source_type, dtype: float64
# 7
# <><><><><>
# source_class:
# groundwater    0.770905
# surface        0.224429
# unknown        0.004666
# Name: source_class, dtype: float64
# 3
# <><><><><>
# waterpoint_type:
# communal standpipe             0.480358
# hand pump                      0.294219
# other                          0.107422
# communal standpipe multiple    0.102739
# improved spring                0.013190
# cattle trough                  0.001954
# dam                            0.000118
# Name: waterpoint_type, dtype: float64
# 7
# <><><><><>
# waterpoint_type_group:
# communal standpipe    0.583098
# hand pump             0.294219
# other                 0.107422
# improved spring       0.013190
# cattle trough         0.001954
# dam                   0.000118
# Name: waterpoint_type_group, dtype: float64
# 6
# <><><><><>

# %%
#Dialing in on the specifics of just our categorical columns
for col in cat_cols:
    print(f'{col}:')
    print(df[col].value_counts(normalize=True))
    print('<>'*5)
# Out:
# status_group:
# functional        0.54304
# non functional    0.45696
# Name: status_group, dtype: float64
# <><><><><>
# date_recorded:
# 2011-03-15    0.009635
# 2011-03-17    0.009400
# 2013-02-03    0.009197
# 2011-03-14    0.008760
# 2011-03-16    0.008642
#                 ...
# 2011-09-26    0.000017
# 2011-09-23    0.000017
# 2011-09-13    0.000017
# 2011-09-06    0.000017
# 2011-09-16    0.000017
# Name: date_recorded, Length: 356, dtype: float64
# <><><><><>
# funder:
# Government Of Tanzania          0.162860
# Danida                          0.055878
# Hesawa                          0.039441
# Rwssp                           0.024619
# World Bank                      0.024206
#                                   ...
# Cristan Outrich                 0.000018
# Babtist                         0.000018
# Tajiri Jumbe Lila               0.000018
# Village Council/ Rose Kawala    0.000018
# Pag Church                      0.000018
# Name: funder, Length: 1897, dtype: float64
# <><><><><>
# installer:
# DWE                0.312068
# Government         0.032634
# RWE                0.021630
# Commu              0.019027
# DANIDA             0.018848
#                      ...
# ABD                0.000018
# Mkuluku            0.000018
# VWT                0.000018
# TMP                0.000018
# Mohamad Masanga    0.000018
# Name: installer, Length: 2145, dtype: float64
# <><><><><>
# wpt_name:
# none                   0.059986
# Shuleni                0.029445
# Zahanati               0.013982
# Msikitini              0.009012
# Kanisani               0.005441
#                          ...
# Kwa Mzee Mwanyusi      0.000017
# Kwa Chilumba Jabiri    0.000017
# Kwa Matata Ibrahim     0.000017
# Kwa Ruziro             0.000017
# Kwa Lulu               0.000017
# Name: wpt_name, Length: 37400, dtype: float64
# <><><><><>
# basin:
# Lake Victoria              0.172023
# Pangani                    0.150596
# Rufiji                     0.134358
# Internal                   0.131140
# Lake Tanganyika            0.108348
# Wami / Ruvu                0.100852
# Lake Nyasa                 0.085658
# Ruvuma / Southern Coast    0.075686
# Lake Rukwa                 0.041338
# Name: basin, dtype: float64
# <><><><><>
# subvillage:
# Shuleni            0.008560
# Madukani           0.008526
# Majengo            0.008509
# Kati               0.006323
# Mtakuja            0.004441
#                      ...
# Mtonya B           0.000017
# Mushule            0.000017
# Kafwandi           0.000017
# Nationanal Park    0.000017
# Mwilongalage B     0.000017
# Name: subvillage, Length: 19287, dtype: float64
# <><><><><>
# region:
# Iringa           0.089179
# Shinyanga        0.083889
# Mbeya            0.078145
# Kilimanjaro      0.073765
# Morogoro         0.067482
# Arusha           0.056432
# Kagera           0.055842
# Mwanza           0.051698
# Kigoma           0.047436
# Ruvuma           0.044471
# Pwani            0.044387
# Tanga            0.042905
# Dodoma           0.037076
# Singida          0.035257
# Mara             0.033168
# Tabora           0.033000
# Rukwa            0.030456
# Mtwara           0.029142
# Manyara          0.026666
# Lindi            0.026043
# Dar es Salaam    0.013560
# Name: region, dtype: float64
# <><><><><>
# lga:
# Njombe          0.042164
# Arusha Rural    0.021090
# Moshi Rural     0.021073
# Bariadi         0.019793
# Rungwe          0.018631
#                   ...
# Moshi Urban     0.001331
# Kigoma Urban    0.001196
# Arusha Urban    0.001061
# Lindi Urban     0.000354
# Nyamagana       0.000017
# Name: lga, Length: 125, dtype: float64
# <><><><><>
# ward:
# Igosi            0.005171
# Imalinyi         0.004245
# Siha Kati        0.003908
# Mdandu           0.003891
# Nduruma          0.003655
#                    ...
# Chinugulu        0.000017
# Kirongo          0.000017
# Ukata            0.000017
# Kihangimahuka    0.000017
# Mitole           0.000017
# Name: ward, Length: 2092, dtype: float64
# <><><><><>
# public_meeting:
# True     0.909831
# False    0.090169
# Name: public_meeting, dtype: float64
# <><><><><>
# recorded_by:
# GeoData Consultants Ltd    1.0
# Name: recorded_by, dtype: float64
# <><><><><>
# scheme_management:
# VWC                 0.662840
# WUG                 0.093463
# Water authority     0.056824
# WUA                 0.051958
# Water Board         0.049525
# Parastatal          0.030241
# Private operator    0.019158
# Company             0.019122
# Other               0.013805
# SWC                 0.001748
# Trust               0.001298
# None                0.000018
# Name: scheme_management, dtype: float64
# <><><><><>
# scheme_name:
# K                                 0.021841
# None                              0.020624
# Borehole                          0.017454
# Chalinze wate                     0.012970
# M                                 0.012810
#                                     ...
# Mkunya                            0.000032
# Losaa kia gravity water supply    0.000032
# Kima                              0.000032
# Miga                              0.000032
# BL Kyongwa                        0.000032
# Name: scheme_name, Length: 2696, dtype: float64
# <><><><><>
# permit:
# True     0.689742
# False    0.310258
# Name: permit, dtype: float64
# <><><><><>
# extraction_type:
# gravity                      0.451048
# nira/tanira                  0.137171
# other                        0.108264
# submersible                  0.080166
# swn 80                       0.061704
# mono                         0.048262
# india mark ii                0.040395
# afridev                      0.029799
# ksb                          0.023802
# other - rope pump            0.007597
# other - swn 81               0.003858
# windmill                     0.001971
# india mark iii               0.001634
# cemo                         0.001516
# other - play pump            0.001432
# walimi                       0.000809
# climax                       0.000539
# other - mkulima/shinyanga    0.000034
# Name: extraction_type, dtype: float64
# <><><><><>
# extraction_type_group:
# gravity            0.451048
# nira/tanira        0.137171
# other              0.108264
# submersible        0.103969
# swn 80             0.061704
# mono               0.048262
# india mark ii      0.040395
# afridev            0.029799
# rope pump          0.007597
# other handpump     0.006132
# other motorpump    0.002055
# wind-powered       0.001971
# india mark iii     0.001634
# Name: extraction_type_group, dtype: float64
# <><><><><>
# extraction_type_class:
# gravity         0.451048
# handpump        0.276834
# other           0.108264
# submersible     0.103969
# motorpump       0.050317
# rope pump       0.007597
# wind-powered    0.001971
# Name: extraction_type_class, dtype: float64
# <><><><><>
# management:
# vwc                 0.682114
# wug                 0.109410
# water board         0.049407
# wua                 0.042703
# private operator    0.033202
# parastatal          0.029749
# water authority     0.015228
# other               0.014217
# company             0.011539
# unknown             0.009450
# other - school      0.001668
# trust               0.001314
# Name: management, dtype: float64
# <><><><><>
# management_group:
# user-group    0.883633
# commercial    0.061283
# parastatal    0.029749
# other         0.015885
# unknown       0.009450
# Name: management_group, dtype: float64
# <><><><><>
# payment:
# never pay                0.426807
# pay per bucket           0.151338
# pay monthly              0.139815
# unknown                  0.137019
# pay when scheme fails    0.065932
# pay annually             0.061350
# other                    0.017738
# Name: payment, dtype: float64
# <><><><><>
# payment_type:
# never pay     0.426807
# per bucket    0.151338
# monthly       0.139815
# unknown       0.137019
# on failure    0.065932
# annually      0.061350
# other         0.017738
# Name: payment_type, dtype: float64
# <><><><><>
# water_quality:
# soft                  0.855485
# salty                 0.081800
# unknown               0.031551
# milky                 0.013544
# coloured              0.008254
# salty abandoned       0.005711
# fluoride              0.003369
# fluoride abandoned    0.000286
# Name: water_quality, dtype: float64
# <><><><><>
# quality_group:
# good        0.855485
# salty       0.087511
# unknown     0.031551
# milky       0.013544
# colored     0.008254
# fluoride    0.003655
# Name: quality_group, dtype: float64
# <><><><><>
# quantity:
# enough          0.558672
# insufficient    0.254683
# dry             0.105165
# seasonal        0.068189
# unknown         0.013291
# Name: quantity, dtype: float64
# <><><><><>
# quantity_group:
# enough          0.558672
# insufficient    0.254683
# dry             0.105165
# seasonal        0.068189
# unknown         0.013291
# Name: quantity_group, dtype: float64
# <><><><><>
# source:
# spring                  0.286706
# shallow well            0.283017
# machine dbh             0.186460
# river                   0.161916
# rainwater harvesting    0.038626
# hand dtw                0.014723
# lake                    0.012853
# dam                     0.011034
# other                   0.003554
# unknown                 0.001112
# Name: source, dtype: float64
# <><><><><>
# source_type:
# spring                  0.286706
# shallow well            0.283017
# borehole                0.201183
# river/lake              0.174769
# rainwater harvesting    0.038626
# dam                     0.011034
# other                   0.004666
# Name: source_type, dtype: float64
# <><><><><>
# source_class:
# groundwater    0.770905
# surface        0.224429
# unknown        0.004666
# Name: source_class, dtype: float64
# <><><><><>
# waterpoint_type:
# communal standpipe             0.480358
# hand pump                      0.294219
# other                          0.107422
# communal standpipe multiple    0.102739
# improved spring                0.013190
# cattle trough                  0.001954
# dam                            0.000118
# Name: waterpoint_type, dtype: float64
# <><><><><>
# waterpoint_type_group:
# communal standpipe    0.583098
# hand pump             0.294219
# other                 0.107422
# improved spring       0.013190
# cattle trough         0.001954
# dam                   0.000118
# Name: waterpoint_type_group, dtype: float64
# <><><><><>

# %%
#
df[cat_cols].describe()
# Out:
#        status_group date_recorded                  funder installer wpt_name  \
# count         59364         59364                   55729     55709    59364
# unique            2           356                    1897      2145    37400
# top      functional    2011-03-15  Government Of Tanzania       DWE     none
# freq          32237           572                    9076     17385     3561
#
#                 basin subvillage  region     lga   ward public_meeting  \
# count           59364      58993   59364   59364  59364          56050
# unique              9      19287      21     125   2092              2
# top     Lake Victoria    Shuleni  Iringa  Njombe  Igosi           True
# freq            10212        505    5294    2503    307          50996
#
#                     recorded_by scheme_management scheme_name permit  \
# count                     59364             55487       31225  56308
# unique                        1                12        2696      2
# top     GeoData Consultants Ltd               VWC           K   True
# freq                      59364             36779         682  38838
#
#        extraction_type extraction_type_group extraction_type_class management  \
# count            59364                 59364                 59364      59364
# unique              18                    13                     7         12
# top            gravity               gravity               gravity        vwc
# freq             26776                 26776                 26776      40493
#
#        management_group    payment payment_type water_quality quality_group  \
# count             59364      59364        59364         59364         59364
# unique                5          7            7             8             6
# top          user-group  never pay    never pay          soft          good
# freq              52456      25337        25337         50785         50785
#
#        quantity quantity_group  source source_type source_class  \
# count     59364          59364   59364       59364        59364
# unique        5              5      10           7            3
# top      enough         enough  spring      spring  groundwater
# freq      33165          33165   17020       17020        45764
#
#            waterpoint_type waterpoint_type_group
# count                59364                 59364
# unique                   7                     6
# top     communal standpipe    communal standpipe
# freq                 28516                 34615

# %%
((df[cat_cols] == 'None')|(df[cat_cols] == 'none')).sum(axis=0)/len(data)*100
# Out:
# status_group             0.000000
# date_recorded            0.000000
# funder                   0.003367
# installer                0.000000
# wpt_name                 5.998316
# basin                    0.000000
# subvillage               0.000000
# region                   0.000000
# lga                      0.000000
# ward                     0.000000
# public_meeting           0.000000
# recorded_by              0.000000
# scheme_management        0.001684
# scheme_name              1.126263
# permit                   0.000000
# extraction_type          0.000000
# extraction_type_group    0.000000
# extraction_type_class    0.000000
# management               0.000000
# management_group         0.000000
# payment                  0.000000
# payment_type             0.000000
# water_quality            0.000000
# quality_group            0.000000
# quantity                 0.000000
# quantity_group           0.000000
# source                   0.000000
# source_type              0.000000
# source_class             0.000000
# waterpoint_type          0.000000
# waterpoint_type_group    0.000000
# dtype: float64

# %%
((df[cat_cols] == 'Unknown')|(df[cat_cols] == 'unknown')).sum(axis=0)/len(data)*100
# Out:
# status_group              0.000000
# date_recorded             0.000000
# funder                    0.006734
# installer                 0.006734
# wpt_name                  0.005051
# basin                     0.000000
# subvillage                0.000000
# region                    0.000000
# lga                       0.000000
# ward                      0.000000
# public_meeting            0.000000
# recorded_by               0.000000
# scheme_management         0.000000
# scheme_name               0.000000
# permit                    0.000000
# extraction_type           0.000000
# extraction_type_group     0.000000
# extraction_type_class     0.000000
# management                0.944444
# management_group          0.944444
# payment                  13.693603
# payment_type             13.693603
# water_quality             3.153199
# quality_group             3.153199
# quantity                  1.328283
# quantity_group            1.328283
# source                    0.111111
# source_type               0.000000
# source_class              0.466330
# waterpoint_type           0.000000
# waterpoint_type_group     0.000000
# dtype: float64

# %%
df[cat_cols].isna().sum()
# Out:
# status_group                 0
# date_recorded                0
# funder                    3635
# installer                 3655
# wpt_name                     0
# basin                        0
# subvillage                 371
# region                       0
# lga                          0
# ward                         0
# public_meeting            3314
# recorded_by                  0
# scheme_management         3877
# scheme_name              28139
# permit                    3056
# extraction_type              0
# extraction_type_group        0
# extraction_type_class        0
# management                   0
# management_group             0
# payment                      0
# payment_type                 0
# water_quality                0
# quality_group                0
# quantity                     0
# quantity_group               0
# source                       0
# source_type                  0
# source_class                 0
# waterpoint_type              0
# waterpoint_type_group        0
# dtype: int64

# %%
(df[cat_cols] == 0).sum()
# Out:
# status_group                 0
# date_recorded                0
# funder                       0
# installer                    0
# wpt_name                     0
# basin                        0
# subvillage                   0
# region                       0
# lga                          0
# ward                         0
# public_meeting            5054
# recorded_by                  0
# scheme_management            0
# scheme_name                  0
# permit                   17470
# extraction_type              0
# extraction_type_group        0
# extraction_type_class        0
# management                   0
# management_group             0
# payment                      0
# payment_type                 0
# water_quality                0
# quality_group                0
# quantity                     0
# quantity_group               0
# source                       0
# source_type                  0
# source_class                 0
# waterpoint_type              0
# waterpoint_type_group        0
# dtype: int64

# %%
df[cat_cols] = df[cat_cols].replace(to_replace=['none','None','unknown', 0, np.nan],
                                    value='Unknown')

# %%
(df[cat_cols] == 'Unknown').sum()
# Out:
# status_group                 0
# date_recorded                0
# funder                    3641
# installer                 3659
# wpt_name                  3566
# basin                        0
# subvillage                 371
# region                       0
# lga                          0
# ward                         0
# public_meeting            8368
# recorded_by                  0
# scheme_management         3878
# scheme_name              28808
# permit                   20526
# extraction_type              0
# extraction_type_group        0
# extraction_type_class        0
# management                 561
# management_group           561
# payment                   8134
# payment_type              8134
# water_quality             1873
# quality_group             1873
# quantity                   789
# quantity_group             789
# source                      66
# source_type                  0
# source_class               277
# waterpoint_type              0
# waterpoint_type_group        0
# dtype: int64

# %% [markdown]
# Categorical determinations:
# - date_recorded - drop
# - funder - maybe keep? use with fancy encoder
# - installer - fancy encoder
# - wpt_name - drop
# - basin - FE
# - subvillage - too many, drop
# - region - use instead of region_code and district_code
# - lga - FE (*droppable*)
# - ward - drop
# - public_meeting - drop
# - recorded_by - drop
# - secheme_magnement - FE
# - secheme_neme - drop
# - permit - binary encode
# - extraction_type & extraction_type_group - drop
# - extraction_type_class - keep, encode
# - management - drop
# - management_group - FE
# - payment - FE
# - payment_type - drop (*droppable*)
# - water_quality - drop
# - quality_group - FE
# - quantity - FE
# - quantity_group - drop (same)
# - source over source_type, keep source_class
# - waterpoint_type_group over waterpoint_type

# %% [markdown]
# ### Testing categorial columns for importance
#
# Do

# %%
# breakdown of status
df['status_group'].value_counts(normalize=True)
# Out:
# functional        0.54304
# non functional    0.45696
# Name: status_group, dtype: float64

# %%
# ratio of funtional to non functional
funct = df['status_group'].value_counts(normalize=True)[0]
ratio = funct/(1-funct)

# %%
def important_feat(data,col):
    temp = data.groupby([col, 'status_group']).size()/len(data)*100
    temp = temp.reset_index(name='total_perc')
    rel = temp.groupby(col)['total_perc'].transform(sum)
    temp['rel_perc'] = temp['total_perc']/rel*100
    
    # make dictionary of categories with ratios later
    return temp

# %%
important_feat(df, 'extraction_type')
# Out:
#               extraction_type    status_group  total_perc    rel_perc
# 0                     afridev      functional    2.019743   67.778406
# 1                     afridev  non functional    0.960178   32.221594
# 2                        cemo      functional    0.075804   50.000000
# 3                        cemo  non functional    0.075804   50.000000
# 4                      climax      functional    0.013476   25.000000
# 5                      climax  non functional    0.040429   75.000000
# 6                     gravity      functional   27.029850   59.926800
# 7                     gravity  non functional   18.074928   40.073200
# 8               india mark ii      functional    2.435820   60.300250
# 9               india mark ii  non functional    1.603666   39.699750
# 10             india mark iii      functional    0.074119   45.360825
# 11             india mark iii  non functional    0.089280   54.639175
# 12                        ksb      functional    1.184219   49.752300
# 13                        ksb  non functional    1.196011   50.247700
# 14                       mono      functional    1.822653   37.766143
# 15                       mono  non functional    3.003504   62.233857
# 16                nira/tanira      functional    9.116636   66.461992
# 17                nira/tanira  non functional    4.600431   33.538008
# 18                      other      functional    1.733374   16.010580
# 19                      other  non functional    9.093053   83.989420
# 20  other - mkulima/shinyanga  non functional    0.003369  100.000000
# 21          other - play pump      functional    0.048851   34.117647
# 22          other - play pump  non functional    0.094333   65.882353
# 23          other - rope pump      functional    0.493565   64.966741
# 24          other - rope pump  non functional    0.266155   35.033259
# 25             other - swn 81      functional    0.202143   52.401747
# 26             other - swn 81  non functional    0.183613   47.598253
# 27                submersible      functional    4.416818   55.095608
# 28                submersible  non functional    3.599825   44.904392
# 29                     swn 80      functional    3.513914   56.947857
# 30                     swn 80  non functional    2.656492   43.052143
# 31                     walimi      functional    0.038744   47.916667
# 32                     walimi  non functional    0.042113   52.083333
# 33                   windmill      functional    0.084226   42.735043
# 34                   windmill  non functional    0.112863   57.264957

# %%
important_feat(df, 'management')
# Out:
#           management    status_group  total_perc   rel_perc
# 0            Unknown      functional    0.377333  39.928699
# 1            Unknown  non functional    0.567684  60.071301
# 2            company      functional    0.449768  38.978102
# 3            company  non functional    0.704130  61.021898
# 4              other      functional    0.850684  59.834123
# 5              other  non functional    0.571053  40.165877
# 6     other - school      functional    0.038744  23.232323
# 7     other - school  non functional    0.128024  76.767677
# 8         parastatal      functional    1.716529  57.701019
# 9         parastatal  non functional    1.258338  42.298981
# 10  private operator      functional    2.486355  74.885845
# 11  private operator  non functional    0.833839  25.114155
# 12             trust      functional    0.077488  58.974359
# 13             trust  non functional    0.053905  41.025641
# 14               vwc      functional   34.391214  50.418591
# 15               vwc  non functional   33.820160  49.581409
# 16   water authority      functional    0.751297  49.336283
# 17   water authority  non functional    0.771511  50.663717
# 18       water board      functional    3.655414  73.985680
# 19       water board  non functional    1.285291  26.014320
# 20               wua      functional    2.949599  69.072978
# 21               wua  non functional    1.320666  30.927022
# 22               wug      functional    6.559531  59.953811
# 23               wug  non functional    4.381443  40.046189

# %%
important_feat(df, 'water_quality')
# Out:
#          water_quality    status_group  total_perc   rel_perc
# 0              Unknown      functional    0.444714  14.095035
# 1              Unknown  non functional    2.710397  85.904965
# 2             coloured      functional    0.414393  50.204082
# 3             coloured  non functional    0.411024  49.795918
# 4             fluoride      functional    0.254363  75.500000
# 5             fluoride  non functional    0.082542  24.500000
# 6   fluoride abandoned      functional    0.010107  35.294118
# 7   fluoride abandoned  non functional    0.018530  64.705882
# 8                milky      functional    0.737821  54.477612
# 9                milky  non functional    0.616535  45.522388
# 10               salty      functional    3.739640  45.716639
# 11               salty  non functional    4.440402  54.283361
# 12     salty abandoned      functional    0.293107  51.327434
# 13     salty abandoned  non functional    0.277946  48.672566
# 14                soft      functional   48.409811  56.587575
# 15                soft  non functional   37.138670  43.412425

# %%
drop_cols = ['num_private', 'region_code', 'district_code', 'date_recorded', 
             'wpt_name', 'subvillage', 'ward', 'public_meeting',
             'recorded_by', 'scheme_name', 'extraction_type', 'extraction_type_group',
             'management', 'payment_type', 'water_quality', 'quantity_group',
             'source_type', 'waterpoint_type']
df.drop(columns=drop_cols, inplace=True)

# %% [markdown]
# ## binary encode status_group into `non_functional` with 1 = non_functional, 0 = functional
# df.rename(columns={'status_group':'non_functional'}, inplace=True)
# df['non_functional'] = df['non_functional'].apply(lambda x: 1 if x == 'non functional' else 0)

# %%
# df.to_csv('../../data/data_cleaned.csv')
